# %%
import CornerPlot as cp

# %%
import sys
print(sys.executable)
# Out:
# /data/gravwav/mdrent/miniconda3/envs/bilby_pipe/bin/python

# %%
all_params = cp.all_params
cp.make_cornerplot("../G1124251/pe/test/outdir/final_result/G1124251_data0_1372281638-2548172_analysis_L1_result.hdf5", all_params, mode=True)
# Out:
# Log Bayes factor: 9.253294949399068
# Sampling time: 2.77 hours
# Creating corner plot . . .
# Modes of the posterior:
# {'chirp_mass': np.float64(0.9872189857917153), 'mass_ratio': np.float64(0.6867576243750673), 'a_1': np.float64(0.017262575407955054), 'a_2': np.float64(0.0637623328516081), 'tilt_1': np.float64(1.6636766886254206), 'tilt_2': np.float64(1.8313504074813725), 'phi_12': np.float64(4.928386856198312), 'phi_jl': np.float64(0.032030361255550734), 'lambda_1': np.float64(475.0780622896634), 'lambda_2': np.float64(127.21953782432256), 'luminosity_distance': np.float64(178.36402173048543), 'geocent_time': np.float64(1372281638.232554), 'dec': np.float64(-0.09654394016736878), 'ra': np.float64(2.6081855991775518), 'theta_jn': np.float64(2.5815599909441724), 'psi': np.float64(0.07869056422796267), 'phase': np.float64(0.34558179746870443)}
# Plotting the modes of the posterior
